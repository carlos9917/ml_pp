# %%
import warnings
warnings.filterwarnings('ignore')
import os
import geopandas as gpd
import folium as fl
import pandas as pd
import sqlite3

# %% [markdown]
# ## Quick visualization of the stations

# %%
DPATH="/media/cap/extra_work/data/road_model"
read_sample = pd.read_csv(os.path.join(DPATH,"FYN_T2m_glatmodel_fcst.csv.gz"))

con = sqlite3.connect("/media/cap/extra_work/data/road_model/stations_coords_height.db")

query="SELECT * FROM roadstations;"
df_geo = pd.read_sql(query, con)
con.close()
df_geo.rename(columns={"SID":"site_ID"},inplace=True)
read_sample.drop_duplicates(subset=["site_ID"],inplace=True)

df_locs = pd.merge(read_sample, df_geo, on='site_ID', how='left')

# %%
df_locs.drop(columns=["forecast_temp","model_type","model_ID","init_time","validity_time","lead_hrs"],inplace=True)
#read_sample.drop(columns=["forecast_temp","model_type","model_ID","init],inplace=True)

# %%
df_locs
# Out:
#     site_ID        lon        lat     height
# 0    302400  10.159734  55.400246  70.643433
# 1    302401  10.159734  55.400246  70.643433
# 2    302500  10.372170  55.353410  18.807562
# 3    302501  10.372170  55.353430  18.756945
# 4    302502  10.372240  55.353590  18.479752
# ..      ...        ...        ...        ...
# 70   338800  10.139490  55.163028  13.115735
# 71   342000  10.673460  55.183890  97.013710
# 72   342100  10.651200  55.091840  57.970062
# 73   990900  10.884426  55.306041  25.093767
# 74   991000  10.828761  55.302197   8.428855
#
# [75 rows x 4 columns]

# %%
geo_df = gpd.GeoDataFrame(df_locs,geometry=gpd.points_from_xy(df_locs.lon,df_locs.lat,crs="EPSG:4326"))

# %%
geo_df
# Out:
#     site_ID        lon        lat     height                   geometry
# 0    302400  10.159734  55.400246  70.643433  POINT (10.15973 55.40025)
# 1    302401  10.159734  55.400246  70.643433  POINT (10.15973 55.40025)
# 2    302500  10.372170  55.353410  18.807562  POINT (10.37217 55.35341)
# 3    302501  10.372170  55.353430  18.756945  POINT (10.37217 55.35343)
# 4    302502  10.372240  55.353590  18.479752  POINT (10.37224 55.35359)
# ..      ...        ...        ...        ...                        ...
# 70   338800  10.139490  55.163028  13.115735  POINT (10.13949 55.16303)
# 71   342000  10.673460  55.183890  97.013710  POINT (10.67346 55.18389)
# 72   342100  10.651200  55.091840  57.970062  POINT (10.65120 55.09184)
# 73   990900  10.884426  55.306041  25.093767  POINT (10.88443 55.30604)
# 74   991000  10.828761  55.302197   8.428855  POINT (10.82876 55.30220)
#
# [75 rows x 5 columns]

# %% [markdown]
# ### Plot the stations added in each month over each year

# %%
tooltip = "Click Here For Station name"


loc = 'Stations distribution'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   

m = fl.Map(zoom_start=50, layers_control=True, tiles="OpenStreetMap")
for _, r in geo_df.iterrows():
    #print(r)
    station = r["site_ID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='red')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>ID: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
tooltip = "Click Here For Station name"


loc = 'Stations distribution'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   

m = fl.Map(zoom_start=50, layers_control=True, tiles="OpenStreetMap")
for _, r in geo_df.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='red')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Jan 2022: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)


for _, r in added_202301.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='blue')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Jan 2023: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)
    
m.get_root().html.add_child(fl.Element(title_html))
    
m
m.save('map.html')

# %%
tooltip = "Click Here For Station name"


loc = 'Stations added in February. Red for 2022, Blue for 2023'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   






m = fl.Map(zoom_start=50, layers_control=True, tiles="OpenStreetMap")
for _, r in added_202202.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='red')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Feb 2022: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)


for _, r in added_202302.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='blue')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Feb 2023: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)
    
m.get_root().html.add_child(fl.Element(title_html))
    
m
m.save('map.html')

# %%
tooltip = "Click Here For Station name"


loc = 'Stations added in March. Red for 2022, Blue for 2023'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   






m = fl.Map(zoom_start=50, layers_control=True, tiles="OpenStreetMap")
for _, r in added_202203.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='red')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Mar 2022: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)


for _, r in added_202303.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    icon=fl.Icon(color='blue')
    #l2rc_group.add_child(folium.Marker((df[i, 'Latitude'],df[i, 'Longitude']), icon=icon))
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong>Added Mar 2023: {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)
    
m.get_root().html.add_child(fl.Element(title_html))
    
m
m.save('map.html')

# %%
all_stations.shape[0]
# Out:
# 758

# %%
all_stations
# Out:
#       SID  c2  c3  SID_again                  name        lon        lat  \
# 0    1000   1   4       1000             Kvistgσrd  12.486561  55.995613
# 1    1001   1   4       1001             Hundested  11.921130  55.958218
# 2    1002   1   4       1002              Hiller°d  12.267541  55.908611
# 3    1003   1   4       1003               G°rl°se  12.191520  55.872879
# 4    1004   1   4       1004  Kronp. Frederiks Bro  12.039816  55.843201
# ..    ...  ..  ..        ...                   ...        ...        ...
# 753  9907   1   5       9907                Sprog°  10.965891  55.332045
# 754  9908   5   5       9908          Vestbroen ╪.  10.919014  55.315520
# 755  9909   5   5       9909          Vestbroen V.  10.884426  55.306041
# 756  9910   1   5       9910            Knudshoved  10.828761  55.302197
# 757  9911   5   5       9911              Halsskov  11.124129  55.348572
#
#      creation_date            c8    c9  ...   c13   c14   c15   c16  c17  c18  \
# ...

# %%
tooltip = "Click Here For Station name"


loc = 'All stations in 2023'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   


m = fl.Map(zoom_start=50, layers_control=True, tiles="OpenStreetMap")
for _, r in all_stations.iterrows():
    #print(r)
    station = r["SID"]
    this_lat = r["lat"]
    this_lon = r["lon"]
    #print(f"lat: {this_lat}, lon: {this_lon} for {station}")
    icon=fl.Icon(color='black')
    marker = fl.Marker(
        location=[this_lat, this_lon],
        popup=f"<stong> {station}</stong>",
        tooltip=tooltip, icon=icon)
    marker.add_to(m)



m.get_root().html.add_child(fl.Element(title_html))
    
m
m.save('map.html')

# %%
# Selecting some regions around Fyn, Jutland and NorthWest Zealand 
import leafmap
center_map=[54.87617,10.34985] # this is somewhere in Aero

map_select = leafmap.Map(center=center_map, 
                         zoom = 4, 
                         layers_control=True, 
                         measure_control=False, 
                         attribution_control=False)
# this optional, not sure 
map_select.add_basemap("Stamen.TonerLite")
#this one will export the polygon selection in geojson
map_select
# Out:
# Map(center=[54.87617, 10.34985], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
map_select.save_draw_features("somewhere_midjutland.geojson")
